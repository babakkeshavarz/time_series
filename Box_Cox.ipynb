# %% [markdown]
# <a href="https://colab.research.google.com/github/babakkeshavarz/time_series/blob/main/Box_Cox.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget -nc https://lazyprogrammer.me/course_files/airline_passengers.csv
# Out:
# File ‘airline_passengers.csv’ already there; not retrieving.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from scipy.stats import boxcox

# %%
df = pd.read_csv('airline_passengers.csv' , index_col = 'Month' , parse_dates = True)

# %%
df.plot()
# Out:
# <Axes: xlabel='Month'>

# %%
## to control the increasing amplitudes
df['log_passengers'] = np.log(df['Passengers'])
df['sqrt_passengers'] = np.sqrt(df['Passengers'])
df['log_passengers'].plot()
# Out:
# <Axes: xlabel='Month'>

# %% [markdown]
# Apply BoxCox

# %%
data , lam = boxcox(df['Passengers'])

# %%
df['BoxCox_Passengers'] = data
df['BoxCox_Passengers'].plot()
# Out:
# <Axes: xlabel='Month'>

# %%
df['Passengers'].hist(bins = 30)
# Out:
# <Axes: >

# %%
df['sqrt_passengers'].hist(bins = 30)
# Out:
# <Axes: >

# %%
df['log_passengers'].hist(bins = 30)
# Out:
# <Axes: >

# %%
df['BoxCox_Passengers'].hist(bins = 30)
# Out:
# <Axes: >
